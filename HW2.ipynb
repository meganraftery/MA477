# %% [markdown]
# <h2> ======================================================</h2>
#  <h1>MA477 - Theory and Applications of Data Science</h1>
#   <h1>Homework 2: Pandas</h1>
#
#  <h4>Dr. Valmir Bucaj</h4>
#  <br>
#  United States Military Academy, West Point, AY20-2
# <h2>=======================================================</h2>
#
# <h2> Weight: <font color='red'>50pts</font</h2>

# %% [markdown]
# <hr style="height:3.2px;border:none;color:#333;background-color:#333;" />
#
# <h3> Cadet Name:</h3>
# <br>
# <h3>Date: </h3>
#
# <br>
#
# <font color='red' size='3'> MR MY DOCUMENTATION IDENTIFIES ALL SOURCES USED AND ASSISTANCE RECEIVED IN THIS ASSIGNMENT
# <br>
#
# <b>$\dots \dots$ </b> I DID NOT USE ANY SOURCES OR ASSISTANCE REQUIRING DOCUMENATION IN COMPLETING THIS ASSIGNMENT</font>
#
# <h3> Signature/Initials: Megan Raftery
#
# <hr style="height:3px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# <font size='4'>Complete the following tasks:</font>
#
# <hr style="height:2px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# <h4> Import Pandas and Numpy</h4>
#
# <font color='red'>5pts</font>

# %%
#Enter your code here
import pandas as pd
import numpy as np

# %% [markdown]
# <h4>Read-in the file named <font color='red'>Airbnb_Dataset</font> and assign it to a variable names <font color='red'>abnb</font></h4>(Make sure that the file is in the same folder as your Homework2 JupyterNotebook)
#
# <font color='red'>5pts</font>

# %%
abnb=pd.read_csv('AB_NYC_2019.csv')

# %% [markdown]
# <h4> Show the head of the dataframe</h4>
#
# <font color='red'>5pts</font>

# %%
#Your code goes here
abnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# <h4> Find how many different neighborhoods are there in Manhattan and list all of them? </h4>
#
# <font color='red'>5pts</font>

# %%
#Answer for number of different neighborhoods in Manhattan
ans = abnb[(abnb['neighbourhood_group']=='Manhattan')]
ans['neighbourhood'].nunique()
# Out:
# 32

# %%
#Your answer for the list of all different neighborhoods in Manhattan
ans['neighbourhood'].unique()
# Out:
# array(['Midtown', 'Harlem', 'East Harlem', 'Murray Hill',
#        "Hell's Kitchen", 'Upper West Side', 'Chinatown', 'West Village',
#        'Chelsea', 'Inwood', 'East Village', 'Lower East Side', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Washington Heights',
#        'Financial District', 'Morningside Heights', 'NoHo',
#        'Flatiron District', 'Roosevelt Island', 'Greenwich Village',
#        'Little Italy', 'Two Bridges', 'Nolita', 'Gramercy',
#        'Theater District', 'Tribeca', 'Battery Park City', 'Civic Center',
#        'Stuyvesant Town', 'Marble Hill'], dtype=object)

# %% [markdown]
# <h4> How many different shared rooms are listed?</h4>
#
# <font color='red'>5pts</font>

# %%
#Your answer
abnb['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %% [markdown]
# <h4> Find all the listings of room type <font color='red'> Shared rooms</font> in <font color='red'> Manhattan</font> with a price range of <font color='red'> \$60$-$\$75</font> and that have received over <font color='red'>100 reviews</font></h4>
#
# <font color='red'>10pts</font>

# %%
#Enter your answer here
abnb[(abnb['price']>=60)&(abnb['price']<=75)&(abnb['neighbourhood_group']=='Manhattan')&(abnb['room_type']=='Shared room')&(abnb['number_of_reviews']>=100)]
# Out:
#              id                                               name    host_id  \
# 357       99070                Comfortable Cozy Space in El Barrio     522065
# 2787    1526741               Comfy Couch in a nice and safe apt!!    6486116
# 4229    2774934                 Females only for midtown apt share    1866728
# 6055    4431247  1st Time/Solo/Duo Travelers!Charming Studio Sh...   22382732
# 7652    5763191     BEAUTIFUL APT UPPER WEST SIDE, 68St ONLY GIRLS   29901463
# 11038   8525172  Shared Studio (NO PRIVACY) On The Upper East Side   44887928
# 17818  13971471                    Nice Room in Charming Apartment    8338942
# 31517  24539281             43rd Street “TIME SQUARE”\nSingle bed.   30985759
# 35014  27759146             Cozy corner near Empire State Building  209549523
#
#              host_name neighbourhood_group    neighbourhood  latitude  \
# 357    Liz And Melissa           Manhattan      East Harlem  40.79406
# ...

# %% [markdown]
# <h4> Find the <font color='red'>minimum</font>, <font color='red'>maximum</font>, and <font color='red'>average</font> values for both <font color='red'>price</font> and <font color='red'> number of reviews</font> for the listings in each of the different neighbourhoods of Manhattan</h4>
#
# <font color='red'>5pts</font>

# %%
#Your answer
ans.groupby(by='neighbourhood').agg({'price':[np.max,np.min,np.std],'number_of_reviews':[np.max,np.min,np.std]})
# Out:
#                      price                  number_of_reviews
#                       amax amin         std              amax amin        std
# neighbourhood
# Battery Park City    7500   55   974.671043  205               0    26.936933
# Chelsea              6800   12   331.934759  375               0    42.548253
# Chinatown            1500   41   128.672260  318               0    43.502104
# Civic Center         950    50   146.714397  319               0    44.670416
# East Harlem          9999   30   314.802327  325               0    51.751879
# East Village         3750   10   198.708649  451               0    49.196771
# Financial District   3000   12   168.425509  285               0    23.274267
# Flatiron District    2000   65   345.657831  177               0    35.325877
# Gramercy             3000   45   257.566843  323               0    42.621756
# Greenwich Village    6000   43   434.838926  209               0    31.120976
# ...

# %% [markdown]
# <h2><font color='red'>Challenging!!!</font></h2>
#
# <br>
#
# Find all the listings that have any version (upper case, lower case, mix etc.) of the following two phrases <b> Females Only</b> and <b> Comfy Couch</b> in the <font color='red'>name</font> column of the <b> abnb</b> dataframe. Display only the <b>id, name, host_name, price,</b> and <b> neighbourhood_group</b>
#
# <font color='red'>10pts</font>

# %%
#Don't change this
pd.set_option('display.max_colwidth', -1)

# %%
#Your answer goes here

abnb_strings = abnb.loc[abnb.name.str.contains('comfy couch|females only', na=False,case=False)]

abnb_strings[['id','name','host_name','price','neighbourhood_group']]

#https://stackoverflow.com/questions/51026771/python-case-insensitive-in-a-string-or-case-ignore
#https://stackoverflow.com/questions/37011734/pandas-dataframe-str-contains-and-operation
# Out:
#              id                                                name  \
# 2787   1526741   Comfy Couch in a nice and safe apt!!
# 4229   2774934   Females only for midtown apt share
# 7704   5824543   Private room for 2 (10 min to city) - Females only
# 13418  10057854  Room in LIC - females only please
# 14140  10853955  Sunny, private room; Quick to NYC. Females only.
# 14524  11442670  Females Only Private Room JFK 1Omin
# 15322  12274909  Beautiful spacious bedroom BayRidge FEMALES only
# 15882  12847720  Prime location, close to everything. Females only
# 16254  13100277  Bright, inviting room-quick to NYC, females only.
# 16552  13256651  Large Comfy Couch in South Prospect Park
# 19392  15476467  Large Space and Comfy Couch in New Apartment
# 20719  16425205  Room for rent (females ONLY)
# 21323  16974219  Big Room with Queen Bed&Comfy Couch
# 21813  17531493  Cute Room in Upper West Side (FEMALES ONLY)
# 22031  17728208  Bright and Clean One Bedroom - Females Only!
# ...

# %% [markdown]
# <hr style="height:3px;border:none;color:#333;background-color:#333;" />
# <h3> Work Cited</h3>

# %%
Ritchie Ng "Selecting Multiple Rows and Columns",https://www.ritchieng.com/pandas-selecting-multiple-rows-and-columns/
    This website helped me with the pd.loc() function. It taught me that I could simply write ":" in the row argument in order
    to select all of the rows and only certain columns. Without the aid of this website, I would not have been able to complete this problem.
    West Point, NY 27 January 2020.
    
"String Contains and Operation", https://stackoverflow.com/questions/37011734/pandas-dataframe-str-contains-and-operation, I used this website to learn
    about the df.str.contains() function. I learned that I can use this function to find data entries that contain a certain string or phrase and 
    create a new dataframe with the results. Without this website I would not have been able to solve this problem. West Point, NY 27 January 2020.
    
"Case Insensitive in a String or Case Ignore", https://stackoverflow.com/questions/51026771/python-case-insensitive-in-a-string-or-case-ignore,
    I used this website to learn how to include any string containing the desired phrases regardless of capitalization.
    I learned that I can add in the command 'case = False' to achieve my desired goal. West Point, NY 27 January 2020.
